# %%
# !unzip ./Corpora.zip -d ./
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# !python ./OpenNMT-py/setup.py install
# !pip install -U torchtext
# !nvidia-smi
# !mkdir ./data ./models ./predictions

# %%
# !python OpenNMT-py/preprocess.py \
-train_src ./Corpora/En2Fa-Translation/Train/train.en \
-train_tgt ./Corpora/En2Fa-Translation/Train/train.fa \
-valid_src ./Corpora/En2Fa-Translation/Dev/dev.en \
-valid_tgt ./Corpora/En2Fa-Translation/Dev/dev.fa \
-save_data ./data/trans \
-src_seq_length 50 \
-tgt_seq_length 50 \
-lower

# %%
# !python OpenNMT-py/train.py \
-data ./data/trans \
-src_word_vec_size 512 \
-tgt_word_vec_size 512 \
-encoder_type "rnn" \
-decoder_type "rnn" \
-layers 6 \
-rnn_size 512 \
-rnn_type "LSTM" \
-save_model ./models/trans \
-save_checkpoint_steps 2500 \
-gpu_ranks 0 \
-world_size 1 \
-seed 2020 \
-batch_size 32 \
-normalization "sents" \
-train_steps 50000 \
-early_stopping 0 \
-optim "adam" \
-max_grad_norm 5 \
-dropout 0.4 \
-learning_rate 0.001 \
-learning_rate_decay 0.8 \
-start_decay_steps 10000 \
-decay_steps 5000 \
-decay_method "none" \
-warmup_steps 1000 \
-report_every 500 \
-log_file "stats.txt"

# %%
import os
import subprocess
import matplotlib.pyplot as plt

# %%
def execute(cmd):
    process = subprocess.Popen(
        cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE
    )
    (result, error) = process.communicate()
    rc = process.wait()
    if rc != 0:
        print ("Error: failed to execute command: ", cmd)
        print (error.rstrip().decode("utf-8"))
    return result.rstrip().decode("utf-8"), error.rstrip().decode("utf-8")

# %%
files_list = sorted(
    os.listdir('./models'), 
    key=lambda x: int(x[len('trans_step_'):-3])
)
bleu_file = open('bleu_results.txt', 'w')
for file in files_list:
    if file.startswith('trans'):
        num_step = int(file[len('trans_step_'):-3])
        pred_file = f'pred_step_{num_step}.txt'
        out = execute(f'python OpenNMT-py/translate.py -model ./models/{file} \
        -src ./Corpora/En2Fa-Translation/Dev/dev.en \
        -output ./predictions/{pred_file} -replace_unk')
        out = execute(f'perl OpenNMT-py/tools/multi-bleu.perl \
        ./Corpora/En2Fa-Translation/Dev/dev.fa < ./predictions/{pred_file}')
        print(f'Model {file} evaluation finished.')
        print(out)
        bleu_file.write(f'{num_step} {out[0]}\n')
bleu_file.close()

# %%
# !python OpenNMT-py/translate.py \
-model ./models/trans_step_50000.pt \
-src ./Corpora/En2Fa-Translation/Test/test.en \
-output ./predictions/test.txt \
-replace_unk -verbose
# Out:
# [2020-05-28 15:41:54,759 INFO] Translating shard 0.
# /pytorch/aten/src/ATen/native/BinaryOps.cpp:66: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
#
# SENT 1: ['hello', ',', 'do', 'we', 'drive', 'together', 'to', 'Hanover', 'on', 'the', 'twenty-eighth', 'of', 'March', '?']
# PRED 1: سلام ، ما میتوانیم در مزرعه پرورش صحبت کنیم ؟
# PRED SCORE: -9.2768
#
# SENT 2: ['it', 'is', 'more', 'comfortable', 'by', 'train', '.']
# PRED 2: آن کمی pool .
# PRED SCORE: -5.8298
#
# SENT 3: ['do', 'you', 'go', 'by', 'car', 'and', 'I', 'go', 'by', 'train', '?']
# PRED 3: آیا شما تا یازده به خانه من بیایی ؟
# PRED SCORE: -7.6610
#
# SENT 4: ['I', 'would', 'like', 'to', 'go', 'by', 'train', '.', 'and', 'what', 'would', 'you', 'like', '?']
# PRED 4: من دوست دارم تا شما بپرسم . اگر شما برای شما چطور است ؟
# PRED SCORE: -13.5178
#
# SENT 5: ['if', 'we', 'take', 'the', '$I-$C-$E', 'train', 'at', 'six', 'past', 'seven', ',', 'we', 'will', 'arrive', 'at', 'twenty-five', 'past', 'eight', '.']
# PRED 5: اگر ما ساعت ساعت شش صبح ، ما ما میتوانیم ساعت ساعت شش بعد از ظهر .
# PRED SCORE: -15.0150
#
# SENT 6: ['which', 'cafe', '?']
# PRED 6: کجا ؟
# PRED SCORE: -2.2911
#
# SENT 7: ['the', 'cafe', 'at', 'platform', 'fourteen', '.']
# PRED 7: یک رستوران .
# PRED SCORE: -2.9103
#
# SENT 8: ['in', 'any', 'case', 'a', 'cheap', 'hotel', '.']
# PRED 8: در زمانی در هتل .
# PRED SCORE: -3.7723
#
# SENT 9: ['what', 'did', 'you', 'say', ',', 'please', '?']
# PRED 9: نظر شما چیست ، لطفا ؟
# PRED SCORE: -2.2463
#
# SENT 10: ['and', 'how', 'much', 'is', 'a', 'single', 'room', '?']
# PRED 10: و در هتل پرواز است ؟
# PRED SCORE: -6.0235
#
# SENT 11: ['we', 'can', 'take', 'a', 'taxi', 'from', 'the', 'station', 'to', 'the', 'hotel', '.']
# PRED 11: ما میتوانیم یک را در هتل در Hanover .
# PRED SCORE: -9.7775
#
# SENT 12: ['at', 'which', 'hotel', 'do', 'you', 'want', 'to', 'reserve', 'a', 'room', 'now', 'and', 'how', 'much', 'is', 'a', 'single', 'room', '?']
# PRED 12: در هتل Luisenhof که در هتل Luisenhof که ما باید یک اتاق پرواز است ؟
# PRED SCORE: -18.5717
#
# SENT 13: ['okay', ',', 'should', 'we', 'drive', 'back', 'on', 'Friday', 'evening', '?']
# PRED 13: باشه ، ما باید پرواز در جمعه ؟
# PRED SCORE: -4.5717
#
# SENT 14: ['I', 'think', 'we', 'rather', 'drive', 'back', 'at', 'thirty-three', 'past', 'nine', 'then', 'we', 'will', 'arrive', 'at', 'Hamburg', 'at', 'fifty-two', 'past', 'ten', '.']
# PRED 14: من فکر میکنم که ما باید از ساعت ساعت نیم به بعد از آن پس از آن را پرواز میکنم و ساعت ده .
# PRED SCORE: -30.1251
#
# SENT 15: ['fine', 'and', "don't", 'forget', 'your', 'swimming', 'stuff', ',', 'maybe', 'we', 'can', 'go', 'swimming', 'together', '.']
# PRED 15: خوب است . و شما میخواهید به افرادم اطلاع‌ شویم یا ما میتوانیم به چیزی برویم .
# PRED SCORE: -20.9128
#
# SENT 16: ['yes', '.', 'when', 'and', 'where', 'do', 'we', 'want', 'to', 'meet', '?']
# PRED 16: بله . و در زمانی میتوانیم با آن را ملاقات کنیم ؟
# PRED SCORE: -10.6360
#
# SENT 17: ['I', 'prefer', 'the', 'plane', '.']
# PRED 17: من پیشنهاد میکنم .
# PRED SCORE: -1.9934
#
# SENT 18: ['a', 'good', 'idea', '.', 'then', 'we', 'will', 'meet', 'at', 'the', 'airport', 'tomorrow', '.']
# PRED 18: ایده خوبی است . ما همدیگر را ساعت ده ببینیم .
# PRED SCORE: -9.5984
#
# SENT 19: ['no', 'idea', '.', 'we', 'will', 'see', '.', 'it', 'does', 'not', 'matter', '.']
# PRED 19: نظری نبود که این را ببینیم .
# PRED SCORE: -9.2789
#
# SENT 20: ['good', '.', 'let', 'us', 'meet', 'at', 'nine', "o'clock", '.', 'hopefully', 'the', 'plane', "won't", 'be', 'hijacked', 'tomorrow', '.']
# PRED 20: خوب است ، اجازه بدهید ساعت نه همدیگر را ملاقات کنیم ، پس میتوانیم ساعت ساعت یازده .
# PRED SCORE: -13.2123
#
# SENT 21: ['I', 'have', 'already', 'booked', 'two', 'rooms', 'at', 'the', 'Gr"unschnabel', '.']
# PRED 21: من سه hotels hotels دارم .
# PRED SCORE: -5.6661
#
# SENT 22: ['what', 'did', 'you', 'say', '?']
# PRED 22: نظر شما چیست ؟
# PRED SCORE: -0.9314
#
# SENT 23: ['yes', '.', 'we', 'have', 'two', 'rooms', 'at', 'the', 'Gr"unschnabel', '.', 'I', 'will', 'reserve', 'a', 'taxi', 'right', 'now', '.']
# PRED 23: بله . ما یک ساعت یک اتاق را انتخاب میکنم . پس من میتوانم به دفتر را انتخاب کنیم .
# PRED SCORE: -22.7605
#
# SENT 24: ['what', 'is', 'planned', 'for', 'the', 'evening', '?']
# PRED 24: برای شما بعدازظهر چطور است ؟
# PRED SCORE: -2.8700
#
# SENT 25: ['a', 'good', 'idea', '.', 'I', 'have', 'heard', ',', 'Phantom', 'of', 'the', 'opera', 'is', 'supposed', 'to', 'be', 'played', '.']
# PRED 25: یک سوال خوبی است ، من فکر میکنم که یک movie که یک sauna .
# PRED SCORE: -16.8534
#
# SENT 26: ['fine', '.', 'I', 'think', 'we', 'have', 'arranged', 'everything', '.', 'then', 'we', 'will', 'meet', 'tomorrow', '.']
# PRED 26: خوب است ، فکر میکنم آن را انتخاب کردیم که باید آن را برای فردا تنظیم کنیم .
# PRED SCORE: -13.7217
#
# SENT 27: ['hello', '.', 'we', 'have', 'to', 'talk', 'about', 'our', 'trip', 'to', 'Hanover', '.']
# PRED 27: سلام ، ما باید با یک رستوران صحبت کنیم .
# PRED SCORE: -8.3029
#
# SENT 28: ['right', '.', 'we', 'will', 'be', 'at', 'the', 'Expo', 'two', 'thousand', 'in', 'Hanover', 'on', 'the', 'fourth', 'and', 'fifth', 'of', 'September', '.']
# PRED 28: درست است ، ما در ساعت یک روز روز روز شنبه یازدهم و یازدهم آگوست .
# PRED SCORE: -16.0179
#
# SENT 29: ['I', 'have', 'already', 'booked', 'a', 'flight', '.']
# PRED 29: من از قبل از آن رزرو کرده­ام .
# PRED SCORE: -7.5225
#
# SENT 30: ['we', 'will', 'set', 'off', 'at', 'a', 'quarter', 'past', 'eight', 'and', 'arrive', 'at', 'Hanover', 'at', 'twelve', "o'clock", '.']
# PRED 30: ما ما یک ربع در ساعت هشت عصر در Hanover ، ما در Hanover .
# PRED SCORE: -18.3005
#
# SENT 31: ['we', 'will', 'have', 'to', 'meet', 'at', 'the', 'airport', 'at', 'seven', "o'clock", '.']
# PRED 31: ما باید ساعت هشت همدیگر را ملاقات کنیم .
# PRED SCORE: -4.4276
#
# SENT 32: ['we', 'arrive', 'at', 'Hanover', 'at', 'twelve', "o'clock", 'midday', '.']
# PRED 32: ما Hanover در ساعت شش صبح .
# PRED SCORE: -4.7271
#
# SENT 33: ['fine', '.', 'which', 'hotel', 'do', 'you', 'have', 'in', 'mind', '?']
# PRED 33: خوب است . در هتل هتل است ؟
# PRED SCORE: -7.5282
#
# SENT 34: ['the', 'Intercontinental', 'is', 'my', 'favourite', 'hotel', 'in', 'Hanover', '.']
# PRED 34: در هتل در هتل Hanover .
# PRED SCORE: -7.1184
#
# SENT 35: ['thank', 'you', '.', 'how', 'do', 'we', 'go', 'back', 'again', 'to', 'Hamburg', '?']
# PRED 35: متشکرم ، خیلی هم هم از آن میبینم ؟
# PRED SCORE: -9.1146
#
# SENT 36: ['we', 'will', 'go', 'back', 'by', 'train', 'on', 'the', 'fifth', 'of', 'September', '.']
# PRED 36: ما از دوازده تا سیزدهم برویم .
# PRED SCORE: -6.0378
#
# SENT 37: ['the', 'best', 'thing', 'is', 'we', 'meet', 'at', 'the', 'train', 'station', 'at', 'eight', "o'clock", '.']
# PRED 37: زودترین زمان است که ما ساعت نه تا دوازده .
# PRED SCORE: -9.7249
#
# SENT 38: ['exactly', '.', 'the', 'train', 'leaves', 'Hanover', 'at', 'six', 'minutes', 'after', 'eight', '.']
# PRED 38: دقیقا دقیقا ساعت هشت ساعت شش عصر .
# PRED SCORE: -6.8643
#
# SENT 39: ['we', 'leave', 'Hanover', 'at', 'eight', "o'clock", 'and', 'arrive', 'at', 'Hamburg', 'at', 'half', 'past', 'nine', '.']
# PRED 39: ما در ساعت هشت و نیم در هتل و نیم .
# PRED SCORE: -9.9157
#
# SENT 40: ['goodbye', '.']
# PRED 40: خداحافظ .
# PRED SCORE: -0.4468
#
# SENT 41: ['I', 'would', 'prefer', 'to', 'fly', '.']
# PRED 41: من ترجیح میدهم .
# PRED SCORE: -0.8163
#
# SENT 42: ['yes', ',', 'there', 'is', 'a', 'flight', 'at', 'a', 'quarter', 'past', 'nine', '.']
# PRED 42: بله ، یک ساعت ساعت نه و نیم وجود دارد .
# PRED SCORE: -9.2439
#
# SENT 43: ['the', 'plane', 'arrives', 'in', 'Hanover', 'at', 'twenty-five', 'past', 'twelve', '.']
# PRED 43: Hanover که شما ساعت نه و نیم .
# PRED SCORE: -8.5889
#
# SENT 44: ['I', 'did', 'not', 'understand', ',', 'what', 'you', 'said', 'about', 'the', 'hotel', '.']
# PRED 44: نمیدانم نمیدانم که درباره هتل فکر میکنید .
# PRED SCORE: -8.7767
#
# SENT 45: ['yes', ',', 'would', 'you', 'please', 'book', 'two', 'rooms', '.']
# PRED 45: بله ، شما میتوانید دو list .
# PRED SCORE: -6.1554
#
# SENT 46: ['the', 'single', 'room', 'costs', 'a', 'hundred', 'Deutsch-marks', '.', 'did', 'I', 'understand', 'you', 'right', '?']
# PRED 46: تنها تنها تنها تنها تنها تنها اتاق اتاق دویست . به نظر شما خوب است ؟
# PRED SCORE: -18.0872
#
# SENT 47: ['where', 'is', 'this', 'hotel', '?']
# PRED 47: کجاست ؟
# PRED SCORE: -0.5507
#
# SENT 48: ['when', 'do', 'we', 'meet', '?']
# PRED 48: چه موقع ملاقات کنیم ؟
# PRED SCORE: -1.6771
#
# SENT 49: ['yes', ',', 'would', 'you', 'please', 'book', 'this', 'hotel', '.']
# PRED 49: بله ، شما را به هتل یادداشت میکنید .
# PRED SCORE: -6.9700
#
# SENT 50: ['please', 'repeat', 'this', 'once', 'again', '.']
# PRED 50: لطفا دوباره دوباره تکرار کنید .
# PRED SCORE: -3.1928
#
# SENT 51: ['do', 'you', 'mean', 'you', 'always', 'stay', 'there', '?']
# PRED 51: آیا شما درباره این اطلاعات دارید ؟
# PRED SCORE: -8.1831
#
# SENT 52: ['fine', ',', 'would', 'you', 'like', 'to', 'do', 'something', 'in', 'the', 'evening', '?']
# PRED 52: خوب است ، آیا شما میخواهید در بعدازظهر ؟
# PRED SCORE: -7.1902
#
# SENT 53: ['unfortunately', 'I', 'did', 'not', 'understand', 'you', '.', 'would', 'you', 'like', 'to', 'go', 'to', 'the', 'cinema', '?']
# PRED 53: متاسفانه من نمیدانم که شما را در مورد چهارشنبه میدهید ؟
# PRED SCORE: -12.4685
#
# SENT 54: ['would', 'you', 'like', 'to', 'go', 'out', 'for', 'a', 'meal', 'afterwards', '?']
# PRED 54: آیا شما میخواهید برای ناهار به بیرون بیایی ؟
# PRED SCORE: -9.8750
#
# SENT 55: ['we', 'still', 'have', 'to', 'plan', 'our', 'return', 'trip', '.']
# PRED 55: ما هنوز باید یک سفر بنویسیم .
# PRED SCORE: -4.3818
#
# SENT 56: ['when', 'do', 'we', 'want', 'to', 'travel', 'back', 'to', 'Hamburg', '?']
# PRED 56: چه زمانی میتوانیم به سفر برویم ؟
# PRED SCORE: -7.3554
#
# SENT 57: ['could', 'you', 'repeat', 'that', 'once', 'again', 'please', '?']
# PRED 57: میشود دوباره دوباره تکرار کنید ؟
# PRED SCORE: -2.1056
#
# SENT 58: ['yes', ',', 'I', 'agree', '.', 'should', 'we', 'also', 'fly', 'back', 'or', 'go', 'by', 'train', '?']
# PRED 58: بله ، من با آن موافقم . و میتوانیم با قطار بخوریم ؟
# PRED SCORE: -13.7293
#
# SENT 59: ['there', 'is', 'a', 'flight', 'leaving', 'Hanover', 'at', 'a', 'quarter', 'past', 'seven', '$P-$M', '.']
# PRED 59: هتل Hanover که پرواز پرواز در ساعت هفت عصر .
# PRED SCORE: -8.9960
#
# SENT 60: ['fine', ',', 'shall', 'I', 'book', 'this', 'flight', '?']
# PRED 60: خوب است ، پس همین الان آن را رزرو میکنم ؟
# PRED SCORE: -5.7026
#
# SENT 61: ['goodbye', '.']
# PRED 61: خداحافظ .
# PRED SCORE: -0.4468
#
# SENT 62: ['no', ',', 'we', 'go', 'on', 'the', 'twenty-third', '.']
# PRED 62: خیر ، ما باید در Hanover .
# PRED SCORE: -4.5741
#
# SENT 63: ['no', ',', 'I', 'suggest', 'to', 'take', 'the', 'train', 'in', 'the', 'morning', '.']
# PRED 63: نه ، من پیشنهاد میکنم که از ساعت نه شروع کنیم .
# PRED SCORE: -5.3816
#
# SENT 64: ['six', "o'clock", 'is', 'too', 'early', ',', 'I', 'propose', 'to', 'take', 'the', 'train', 'at', 'ten', "o'clock", 'in', 'the', 'morning', '.']
# PRED 64: ساعت هشت عصر است ، من فکر میکنم آن را ساعت ده صبح انجام دهیم .
# PRED SCORE: -14.7024
#
# SENT 65: ['do', 'you', 'agree', '?']
# PRED 65: موافق هستید ؟
# PRED SCORE: -1.1600
#
# SENT 66: ['I', 'did', 'not', 'understand', 'that', '.']
# PRED 66: من نفهمیدم .
# PRED SCORE: -1.5278
#
# SENT 67: ['I', 'did', 'not', 'understand', 'that', 'again', '.']
# PRED 67: من متوجه متوجه شدم .
# PRED SCORE: -2.8651
#
# SENT 68: ['I', 'still', 'have', 'not', 'understood', 'anything', '.']
# PRED 68: من هم مشکلی ندارم .
# PRED SCORE: -3.2795
#
# SENT 69: ['I', 'suggest', 'to', 'stay', 'at', 'the', 'hotel', 'Gr"unschnabel', 'in', 'Hanover', '.']
# PRED 69: من پیشنهاد میکنم که در هتل در هتل Hanover .
# PRED SCORE: -4.2047
#
# SENT 70: ['yes', 'please', '.']
# PRED 70: بله دوهفته­ای. .
# PRED SCORE: -0.9705
#
# SENT 71: ['so', 'shall', 'we', 'take', 'the', 'hotel', 'Gr"unschnabel', '?']
# PRED 71: پس ما هتل را Hanover ؟
# PRED SCORE: -3.8854
#
# SENT 72: ['well', 'once', 'again', ',', 'should', 'we', 'stay', 'at', 'the', 'hotel', 'Gr"unschnabel', '?']
# PRED 72: خب در حقیقت ، ما باید در Hanover که آن ؟
# PRED SCORE: -12.2965
#
# SENT 73: ['once', 'again', ',', 'shall', 'we', 'stay', 'at', 'the', 'hotel', 'Gr"unschnabel', '?']
# PRED 73: یکبار است ، ما میتوانیم آن را در Hanover ؟
# PRED SCORE: -10.7788
#
# SENT 74: ['yes', ',', 'that', 'is', 'a', 'good', 'idea', '.']
# PRED 74: بله ، ایده خوبی است .
# PRED SCORE: -0.1211
#
# SENT 75: ['I', 'did', 'not', 'understand', 'that', ',', 'I', 'suggest', 'to', 'go', 'back', 'to', 'Hamburg', 'on', 'the', 'twenty-fourth', 'in', 'the', 'evening', '.']
# PRED 75: من متوجه متوجه شدم که من باید آن را قبل از نهم شروع کنم .
# PRED SCORE: -14.1284
#
# SENT 76: ['yes', 'I', 'agree', ',', 'I', 'propose', 'to', 'take', 'the', 'train', 'again', '.']
# PRED 76: بله ، من هم میتوانم که از ده خودم را معرفی کنم .
# PRED SCORE: -10.2000
#
# SENT 77: ['I', 'agree', ',', 'everything', 'okay', '?']
# PRED 77: موافقم ، آن خوب است ؟
# PRED SCORE: -2.7348
#
# SENT 78: ['hello', '.', 'should', 'we', 'plan', 'our', 'journey', 'to', 'the', 'Expo', 'on', 'October', 'the', 'ninth', '?']
# PRED 78: سلام . و ما باید برای سفر و هشتم اکتبر برویم ؟
# PRED SCORE: -12.9135
#
# SENT 79: ['I', 'would', 'prefer', 'to', 'take', 'the', 'train', '.']
# PRED 79: من ترجیح میدهم که از آن برویم .
# PRED SCORE: -6.1097
#
# SENT 80: ['we', 'could', 'leave', 'Hamburg', 'at', 'twenty-four', 'past', 'seven', 'and', 'we', 'would', 'be', 'in', 'Hanover', 'at', 'thirty-nine', 'past', 'eight', '.']
# PRED 80: ما میتوانیم آن را در بعد از ساعت شش و نیم و ما میتوانیم از ساعت شش .
# PRED SCORE: -22.2319
#
# SENT 81: ['fine', '.', 'and', 'where', 'at', 'the', 'station', '?']
# PRED 81: خوب . و و هتل کجا ؟
# PRED SCORE: -3.9112
#
# SENT 82: ['do', 'you', 'also', 'want', 'to', 'reserve', 'seats', 'for', 'us', '?']
# PRED 82: آیا شما میخواهید به دفتر من بیایید ؟
# PRED SCORE: -7.0162
#
# SENT 83: ['are', 'the', 'single', 'rooms', 'cheap', 'there', '?']
# PRED 83: آیا همیشه پرواز هست ؟
# PRED SCORE: -4.9926
#
# SENT 84: ['three', 'hundred', 'deutschmarks', 'is', 'a', 'bit', 'expensive', '.', "isn't", 'there', 'anything', 'cheaper', '?']
# PRED 84: ساعت سه ایده ایده ایده خوبی است ؟
# PRED SCORE: -10.0582
#
# SENT 85: ['are', 'there', 'single', 'rooms', 'for', 'eighty', 'Deutsch-marks', '?']
# PRED 85: آیا همیشه یک اتاق دویست ؟
# PRED SCORE: -5.9643
#
# SENT 86: ['fine', '.', 'but', 'at', 'which', 'hotel', 'do', 'you', 'want', 'to', 'reserve', 'now', '?']
# PRED 86: خوب . بله . و شما را در دفتر شما ؟
# PRED SCORE: -9.8586
#
# SENT 87: ['where', 'is', 'our', 'hotel', 'and', 'what', 'is', 'its', 'name', '?']
# PRED 87: کجاست در هتل در دفتر شماست ؟
# PRED SCORE: -7.1850
#
# SENT 88: ['at', 'which', 'hotel', 'do', 'you', 'want', 'to', 'reserve', 'for', 'us', 'and', 'where', 'is', 'the', 'hotel', '?']
# PRED 88: در دفتر شما در دفتر من در دفتر من بیایید ؟
# PRED SCORE: -13.0556
#
# SENT 89: ['would', 'you', 'repeat', 'the', 'hotel', 'name', 'then', ',', 'please', '?']
# PRED 89: آیا شما الان آن را تکرار میکنم ، لطفا ؟
# PRED SCORE: -9.2911
#
# SENT 90: ['what', 'is', 'the', 'name', 'of', 'our', 'hotel', '?']
# PRED 90: اسم شما چیست ؟
# PRED SCORE: -3.6568
#
# SENT 91: ['in', 'the', 'evening', 'I', 'would', 'like', 'to', 'relax', 'and', 'maybe', 'go', 'to', 'the', 'sauna', '.', 'what', 'do', 'you', 'think', '?']
# PRED 91: صبح من به دفتر کار بگیرم اگر اگر اگر شما به دفتر شما بیایید ؟
# PRED SCORE: -18.8654
#
# SENT 92: ['okay', '.', 'the', 'program', 'of', 'the', 'evening', 'we', 'can', 'plan', 'later', 'on', '.']
# PRED 92: باشه . پس آن کار ما میتوانیم آن را برای بعد از آن .
# PRED SCORE: -13.8863
#
# SENT 93: ['I', 'would', 'like', 'to', 'take', 'the', 'train', 'at', 'eighteen', 'past', 'nine', '$P-$M', '.', 'is', 'that', 'okay', 'for', 'you', '?']
# PRED 93: من دوست دارم که از ساعت ساعت دوازده ، اگر اگر از آن برای شما مناسب خواهد بود ؟
# PRED SCORE: -17.4446
#
# SENT 94: ['fine', '.', 'see', 'you', 'later', 'then', '.']
# PRED 94: بسیار خوب ، پس میبینمتان .
# PRED SCORE: -3.3888
#
# SENT 95: ['fine', '.', 'at', 'what', 'time', 'would', 'you', 'like', 'to', 'leave', '?']
# PRED 95: خوب است . چه زمانی ؟ میخواهید ؟
# PRED SCORE: -8.2848
#
# SENT 96: ['I', 'would', 'prefer', 'the', 'train', '.']
# PRED 96: من ساعت نه را ترجیح میدهم .
# PRED SCORE: -1.7313
#
# SENT 97: ['that', 'is', 'okay', '.', 'should', 'we', 'meet', 'at', 'the', 'station', 'at', 'eight', "o'clock", 'then', '?']
# PRED 97: بسیار خوب است ، ما هشت ساعت هشت همدیگر را ببینیم ؟
# PRED SCORE: -6.4978
#
# SENT 98: ['okay', '.', 'do', 'you', 'want', 'me', 'to', 'reserve', 'a', 'hotel', 'for', 'us', '?']
# PRED 98: باشه . آیا شما میخواهید با یک رستوران به دفتر من بیایید ؟
# PRED SCORE: -9.7585
#
# SENT 99: ['I', 'would', 'suggest', 'the', 'Stadthotel', ',', 'because', 'it', 'is', 'the', 'cheapest', 'one', '.']
# PRED 99: من پیشنهاد میکنم ، که آن را در هتل است .
# PRED SCORE: -9.7769
#
# SENT 100: ['the', 'Stadthotel', '.']
# PRED 100: در مکان .
# PRED SCORE: -1.9455
#
# SENT 101: ['would', 'you', 'like', 'a', 'single', 'room', 'or', 'a', 'double', 'room', '?']
# PRED 101: آیا شما میخواهید به یک اتاق اطلاعات یا یک لحظه ؟
# PRED SCORE: -9.3932
#
# SENT 102: ['okay', '.', 'should', 'we', 'go', 'to', 'the', 'hotel', 'by', 'taxi', 'immediately', '?']
# PRED 102: باشه . ما ما باید در هتل Hanover ؟
# PRED SCORE: -8.9374
#
# SENT 103: ['would', 'you', 'like', 'to', 'do', 'something', 'in', 'the', 'evening', '?']
# PRED 103: آیا شما میخواهید در عصر بیایی ؟
# PRED SCORE: -5.5013
#
# SENT 104: ['fine', '.', 'I', 'agree', 'with', 'that', '.']
# PRED 104: خوب است . من با آن موافقم .
# PRED SCORE: -1.4846
#
# SENT 105: ['could', 'you', 'find', 'out', 'a', 'train', 'connection', 'for', 'Wednesday', 'evening', '?']
# PRED 105: آیا میتوانید یک پرواز را به ساعت دو بعدازظهر ؟
# PRED SCORE: -11.7253
#
# SENT 106: ['sorry', '.', 'when', 'will', 'we', 'arrive', 'at', 'Hamburg', '?']
# PRED 106: متاسفم . من آن کار را انجام دارم و نه ؟
# PRED SCORE: -13.1467
#
# SENT 107: ['that', 'is', 'okay', '.', 'then', 'we', 'can', 'go', 'back', 'by', 'taxi', '.']
# PRED 107: بسیار خوب است ، ما میتوانیم به خانه بیندازیم .
# PRED SCORE: -9.8046
#
# SENT 108: ['okay', '.', 'goodbye', '.']
# PRED 108: باشه . خداحافظ .
# PRED SCORE: -1.2765
#
# SENT 109: ['hello', '.', 'I', 'call', 'you', 'to', 'plan', 'the', 'journey', 'to', 'Hanover', 'with', 'you', '.']
# PRED 109: سلام . من تماس را با یک تماس در Hanover .
# PRED SCORE: -9.9293
#
# SENT 110: ['yes', ',', 'I', 'would', 'like', 'to', 'leave', 'on', 'Wednesday', 'the', 'twenty-sixth', 'of', 'January', '.']
# PRED 110: بله ، من میتوانم چهارشنبه در دوشنبه بروم .
# PRED SCORE: -7.9528
#
# SENT 111: ['I', 'prefer', 'the', 'plane', '.']
# PRED 111: من پیشنهاد میکنم .
# PRED SCORE: -1.9934
#
# SENT 112: ['fine', '.', 'at', 'what', 'time', 'should', 'we', 'leave', '?']
# PRED 112: خوب است . پس چه ساعتی ؟
# PRED SCORE: -6.2108
#
# SENT 113: ['I', 'propose', 'to', 'leave', 'at', 'nine', "o'clock", 'in', 'the', 'morning', '.']
# PRED 113: پیشنهاد میکنم ساعت نه صبح باشد .
# PRED SCORE: -4.4123
#
# SENT 114: ['where', 'should', 'we', 'meet', '?']
# PRED 114: کجا ملاقات کنیم ؟
# PRED SCORE: -1.9637
#
# SENT 115: ['at', 'which', 'office', 'please', '?']
# PRED 115: مسلما پای ؟
# PRED SCORE: -3.6414
#
# SENT 116: ['fine', '.', 'do', 'you', 'want', 'me', 'to', 'reserve', 'a', 'hotel', 'for', 'us', '?']
# PRED 116: خوب است ، آیا شما با یک رستوران با شما بیایی ؟
# PRED SCORE: -12.9269
#
# SENT 117: ['the', 'hotel', 'is', 'called', 'Prinzenhof', 'and', 'it', 'is', 'in', 'the', 'city', 'center', '.']
# PRED 117: هتل save در هتل K"onigshof راغب است .
# PRED SCORE: -7.9393
#
# SENT 118: ['do', 'you', 'agree', 'on', 'a', 'double', 'room', '?']
# PRED 118: آیا شما به دو برنامه دارید ؟
# PRED SCORE: -6.1742
#
# SENT 119: ['great', '.', 'I', 'will', 'reserve', 'two', 'single', 'rooms', '.']
# PRED 119: عالی است . من دو choices .
# PRED SCORE: -3.7769
#
# SENT 120: ['would', 'you', 'like', 'to', 'go', 'out', 'for', 'a', 'meal', 'in', 'the', 'evening', '?']
# PRED 120: آیا شما میخواهید برای شام کاری بیایی ؟
# PRED SCORE: -6.2391
#
# SENT 121: ['fine', '.', 'I', 'will', 'choose', 'a', 'restaurant', '.']
# PRED 121: خوب است . من یک رستوران میبینمت .
# PRED SCORE: -4.6455
#
# SENT 122: ['I', 'would', 'like', 'to', 'leave', 'on', 'Thursday', 'afternoon', '.']
# PRED 122: من دوست دارم پنجشنبه بعدازظهر .
# PRED SCORE: -4.5705
#
# SENT 123: ['yes', ',', 'I', 'agree', 'with', 'that', '.']
# PRED 123: بله ، با آن موافقم .
# PRED SCORE: -1.3845
#
# SENT 124: ['yes', ',', 'I', 'agree', 'that', 'we', 'leave', 'at', 'five', "o'clock", '.']
# PRED 124: بله ، من با آن موافقم ، از پنج .
# PRED SCORE: -7.7662
#
# SENT 125: ['I', 'think', 'we', 'have', 'talked', 'about', 'everything', '.', 'goodbye', '.']
# PRED 125: من فکر میکنم که باید درباره آن درباره آن صحبت کنیم .
# PRED SCORE: -6.3032
#
# SENT 126: ['should', 'we', 'meet', 'at', 'the', 'Expo', 'in', 'Hanover', 'in', 'June', '?']
# PRED 126: ما باید در سپتامبر همدیگر را ملاقات کنیم ؟
# PRED SCORE: -5.4792
#
# SENT 127: ['yes', ',', 'I', 'thought', ',', 'we', 'would', 'go', 'to', 'Hanover', 'on', 'the', 'ninth', 'and', 'tenth', 'of', 'June', '.']
# PRED 127: بله ، من فکر میکنم ، ما باید در دهم و دهم آگوست .
# PRED SCORE: -8.7928
#
# SENT 128: ['yes', ',', 'I', 'have', 'got', 'a', 'timetable', '.', 'when', 'would', 'you', 'like', 'to', 'go', '?']
# PRED 128: بله ، من در شما دوست دارم یا شما دوست دارید ؟
# PRED SCORE: -11.0229
#
# SENT 129: ['"ahm', 'there', 'is', 'a', 'train', 'leaving', 'Hamburg', 'at', 'twenty-four', 'past', 'ten', '.', 'it', 'arrives', 'at', 'Hanover', 'at', 'thirty-nine', 'past', 'eleven', '.']
# PRED 129: اوم یک جایی که از ساعت نه و یک بازی هستم و من باید از ساعت نه و یازده صبح .
# PRED SCORE: -26.7838
#
# SENT 130: ['I', 'agree', '.', 'then', 'we', 'could', 'have', 'breakfast', 'together', '.']
# PRED 130: موافقم . ما میتوانیم با شام توافق کنیم .
# PRED SCORE: -8.4107
#
# SENT 131: ['I', 'agree', '.', 'we', 'need', 'a', 'hotel', 'in', 'Hanover', '.']
# PRED 131: موافقم ، ما با یک رستوران Hanover .
# PRED SCORE: -8.0962
#
# SENT 132: ['unfortunately', 'I', 'did', 'not', 'understand', 'you', '.']
# PRED 132: متاسفانه من شما را نفهمیدم .
# PRED SCORE: -2.5871
#
# SENT 133: ['in', 'May', 'on', 'the', 'eighteenth', 'and', 'nineteenth', 'of', 'May', 'we', 'are', 'going', 'together', 'to', 'Hanover', '.']
# PRED 133: در ژوئن ژوئن تا نوزدهم آوریل ، در یک قرار دیگر در آن موضوع .
# PRED SCORE: -14.7297
#
# SENT 134: ['I', 'would', 'like', 'to', '"ahm', 'go', 'by', 'plane', '.', 'do', 'you', 'have', 'a', 'plan', '?']
# PRED 134: من دوست دارم که شما را با شما با شما کار را انجام دهم ؟
# PRED SCORE: -14.1442
#
# SENT 135: ['I', 'would', 'like', 'to', 'fly', 'and', 'to', 'be', 'in', 'Hanover', 'at', 'about', 'ten', "o'clock", '.']
# PRED 135: من میخواهم با آن را در Hanover تا هشت صبح .
# PRED SCORE: -12.1365
#
# SENT 136: ['where', 'should', 'we', 'meet', '?']
# PRED 136: کجا ملاقات کنیم ؟
# PRED SCORE: -1.9637
#
# SENT 137: ['should', 'we', 'meet', 'at', 'the', 'meeting', 'point', 'at', 'the', 'airport', '?']
# PRED 137: ما همدیگر را در ساعت هشت ملاقات کنیم ؟
# PRED SCORE: -5.3831
#
# SENT 138: ['would', 'you', 'please', 'repeat', 'that', 'once', 'again', '?']
# PRED 138: آیا شما راجع دوباره تکرار کنم ؟
# PRED SCORE: -6.4800
#
# SENT 139: ['I', 'agree', '.', 'how', 'can', 'I', 'recognize', 'you', '?']
# PRED 139: من از شما موافقم .
# PRED SCORE: -4.1898
#
# SENT 140: ['well', ',', 'when', 'would', 'you', 'like', 'to', 'fly', 'back', '?']
# PRED 140: خوب ، کی کی دارید ؟
# PRED SCORE: -4.9385
#
# SENT 141: ['I', 'agree', '.', 'when', 'exactly', 'does', 'the', 'plane', 'take', 'off', '?']
# PRED 141: من آن را با آن است . فکر میکنم که امکان دارد ؟
# PRED SCORE: -14.7375
#
# SENT 142: ['please', 'repeat', 'that', 'once', 'again', '.']
# PRED 142: لطفا دوباره دوباره تکرار کنید .
# PRED SCORE: -3.0507
#
# SENT 143: ['that', 'sounds', 'great', '.', '"ahm', ',', 'fine', ',', 'you', 'arrange', 'the', 'flight', '.']
# PRED 143: عالی به نظر میرسد ، آه شما میتوانی به نظر خاصی .
# PRED SCORE: -14.1055
#
# SENT 144: ['do', 'you', 'want', 'me', 'to', '"ah', 'book', 'the', 'hotel', '?', 'do', 'you', 'have', 'any', 'preferences', '?']
# PRED 144: آیا شما میخواهید که شما را در دفتر من بازی میکنم ؟
# PRED SCORE: -14.1835
#
# SENT 145: ['a', 'single', 'room', 'and', 'it', 'is', 'important', 'for', 'you', 'to', 'have', 'a', 'bar', '.']
# PRED 145: یک یک اتاق برای من بسیار خوب است . برای شما یک کار را انجام دهیم .
# PRED SCORE: -16.3310
#
# SENT 146: ['I', 'think', 'there', 'is', 'a', 'TV', 'in', 'all', 'the', 'hotels', '.']
# PRED 146: من فکر میکنم یک جلسه در هتل است .
# PRED SCORE: -7.9421
#
# SENT 147: ['there', 'is', 'a', 'hotel', 'near', 'the', 'fairground', ',', 'but', 'it', 'is', 'very', 'expensive', '.']
# PRED 147: هتل Zentral وجود دارد ، بله ، آن piano است .
# PRED SCORE: -9.1925
#
# SENT 148: ['I', 'agree', '.', 'a', 'single', 'room', 'costs', 'three', 'hundred', 'Deutsch-marks', 'a', 'night', '.']
# PRED 148: من با دو و سه شب دلپذیر هستم .
# PRED SCORE: -11.7166
#
# SENT 149: ['okay', '.', 'I', 'book', 'the', 'hotel', '.']
# PRED 149: باشه . من آنجا را خواهم ­دید .
# PRED SCORE: -3.1022
#
# SENT 150: ['"ahm', 'should', 'we', 'meet', 'on', 'May', 'the', 'eighteenth', 'in', 'the', 'evening', '?']
# PRED 150: اوهوم ما میتوانیم جمعه نوزدهم آوریل ملاقات کنیم ؟
# PRED SCORE: -6.3404
#
# SENT 151: ['okay', '.', 'should', 'we', 'meet', 'at', 'the', 'hotel', 'at', 'half', 'past', 'seven', '?']
# PRED 151: باشه . ما میتوانیم ساعت یک و نیم همدیگر را ملاقات کنیم ؟
# PRED SCORE: -8.4820
#
# SENT 152: ['fine', '.', 'we', 'still', 'have', 'to', 'arrange', 'the', 'ride', 'from', 'the', 'airport', 'to', 'the', 'hotel', '.']
# PRED 152: خوب است ، ما باید آن را هم از فرودگاه .
# PRED SCORE: -9.2021
#
# SENT 153: ['I', 'did', 'not', 'understand', 'that', '.']
# PRED 153: من نفهمیدم .
# PRED SCORE: -1.5278
#
# SENT 154: ['I', 'suggest', 'we', 'take', 'the', 'subway', 'to', 'the', 'hotel', '.']
# PRED 154: من پیشنهاد میکنم که در هتل Georgengarten .
# PRED SCORE: -7.5778
#
# SENT 155: ['the', 'subway', 'takes', 'about', 'twenty', 'minutes', 'to', 'the', 'station', '.']
# PRED 155: its دویست و هشتم در ایستگاه .
# PRED SCORE: -5.7273
#
# SENT 156: ['I', 'agree', '.', 'then', 'we', 'have', 'to', 'have', 'dinner', 'earlier', '.']
# PRED 156: موافقم ، ما میتوانیم با یک شام با توافق برسیم .
# PRED SCORE: -11.1912
#
# SENT 157: ['yes', '.', 'is', 'everything', 'okay', 'so', 'far', 'then', '?']
# PRED 157: بله . آن چیز خیلی خوب است ؟
# PRED SCORE: -7.0836
#
# SENT 158: ['yes', ',', 'well', 'see', 'you', 'on', 'the', 'eighteenth', 'then', '.']
# PRED 158: بله ، پس شما را هجدهم میبینم .
# PRED SCORE: -3.0946
#
# SENT 159: ['hello', '.', 'I', 'would', 'like', 'to', 'go', 'with', 'you', 'to', 'the', 'Expo', 'in', 'Hanover', '.']
# PRED 159: سلام . من میخواهم با شما با شما بروم .
# PRED SCORE: -10.2317
#
# SENT 160: ['I', 'did', 'not', 'understand', 'that', '.', 'would', 'you', 'prefer', 'to', 'fly', 'or', 'to', 'drive', '?']
# PRED 160: من نمیدانم که شما را ترجیح کنید یا ترجیح میدهم یا نه ؟
# PRED SCORE: -15.4075
#
# SENT 161: ['I', 'would', 'like', 'to', 'be', 'in', 'Hanover', 'until', 'noon', ',', 'but', 'I', 'still', 'do', 'not', 'know', 'if', 'you', 'want', 'to', 'fly', 'or', 'to', 'drive', '.']
# PRED 161: من مایل هستم ، من از ساعت نه تا دوازده ، اگر من دوست دارم که شما را در دفتر شماست .
# PRED SCORE: -26.6600
#
# SENT 162: ['that', 'sounds', 'very', 'good', '.', 'where', 'should', 'we', 'meet', '?']
# PRED 162: خوب به نظر میرسد ، ما ما باید ملاقات کنیم ؟
# PRED SCORE: -7.1478
#
# SENT 163: ['yes', 'fine', '.', 'how', 'would', 'half', 'past', 'seven', 'suit', 'you', '?']
# PRED 163: بله خوب است ساعت ساعت نیم برای شما خوب است ؟
# PRED SCORE: -6.1926
#
# SENT 164: ['fine', '.', 'I', 'have', 'a', 'list', 'of', 'hotels', 'for', 'Hanover', '.']
# PRED 164: خوب است . من یک list hotels .
# PRED SCORE: -3.9707
#
# SENT 165: ['I', 'would', 'prefer', 'a', 'hotel', 'in', 'the', 'city', 'center', ',', 'then', 'we', 'can', 'do', 'something', 'in', 'the', 'evening', '.']
# PRED 165: من ترجیح میدهم که از آن را در Schlosshotel میکنم و سپس ما میتوانیم آن را در بعد در آن روز انجام دهیم .
# PRED SCORE: -23.1545
#
# SENT 166: ['unfortunately', 'I', 'did', 'not', 'understand', 'that', '.']
# PRED 166: متاسفانه آن را نفهمیدم .
# PRED SCORE: -2.6022
#
# SENT 167: ['I', 'could', 'not', 'understand', 'you', 'again', '.']
# PRED 167: من نمیتوانم به شما نمیتوانم ببینم .
# PRED SCORE: -7.1140
#
# SENT 168: ['fine', '.', 'then', 'I', 'propose', 'the', 'hotel', 'Prinzenhof', ',', 'that', 'is', 'situated', 'in', 'the', 'city', 'center', '.']
# PRED 168: خوب است . پس من در هتل در هتل سالیانه پیشنهاد میکنم ، متاسفانه .
# PRED SCORE: -11.8412
#
# SENT 169: ['did', 'you', 'understand', 'that', 'I', 'have', 'proposed', 'the', 'hotel', 'Prinzenhof', '?']
# PRED 169: آیا شما پیشنهاد میکنم که در Hanover ؟
# PRED SCORE: -7.5942
#
# SENT 170: ['fine', '.', 'I', 'will', 'book', 'two', 'single', 'rooms', 'for', 'two', 'hundred', 'Deutsch-marks', 'each', '.']
# PRED 170: خوب است . من با دو ساعت دو اتاق choices .
# PRED SCORE: -8.0847
#
# SENT 171: ['do', 'you', 'know', 'a', 'restaurant', 'in', 'Hanover', '?', 'for', 'I', 'do', 'not', 'know', 'any', '.']
# PRED 171: آیا شما list که یک رستوران ، آیا شما نمیدانم .
# PRED SCORE: -15.1417
#
# SENT 172: ['I', 'would', 'really', 'like', 'to', 'have', 'Chinese', 'or', 'Japanese', 'food', ',', 'but', 'not', 'Italien', 'food', '.', 'is', 'that', 'possible', '?']
# PRED 172: من دوست دارم که به پروازها ، اگر شاید شاید شاید شاید شاید شاید شاید بتوانیم زودتر زود زود است ؟
# PRED SCORE: -30.6723
#
# SENT 173: ['that', 'is', 'fine', '.', 'then', 'we', 'still', 'have', 'to', 'arrange', 'the', 'return', 'journey', '.', 'do', 'you', 'have', 'a', 'schedule', 'for', 'a', 'return', 'flight', '?']
# PRED 173: بسیار خوب است ، ما باید آن را در Hanover که ما باید در یک رستوران دلپذیر کنیم ؟
# PRED SCORE: -25.1164
#
# SENT 174: ['I', 'have', 'to', 'be', 'back', 'in', 'Hamburg', 'on', 'Friday', 'at', 'three', "o'clock", '$P-$M', 'at', 'the', 'latest', '.']
# PRED 174: من باید جمعه تا سه بعد از ظهر را سمینار دارم .
# PRED SCORE: -11.0214
#
# SENT 175: ['I', 'did', 'not', 'understand', 'when', 'the', 'plane', 'leaves', 'Hanover', 'and', 'when', 'it', 'is', 'supposed', 'to', 'arrive', 'at', 'Hamburg', '.']
# PRED 175: نمیدانم نمیدانم که در هتل در هتل است و من باید در هتل وجود دارد .
# PRED SCORE: -18.9703
#
# SENT 176: ['I', 'did', 'not', 'understand', 'that', 'yet', '.']
# PRED 176: من متوجه متوجه شدم .
# PRED SCORE: -2.1388
#
# SENT 177: ['that', 'is', 'fine', '.', 'when', 'does', 'the', 'plane', 'leave', 'Hanover', '?']
# PRED 177: خوب است . آیا شما فکر دارید که آنجا Hanover ؟
# PRED SCORE: -9.5199
#
# SENT 178: ['then', 'we', 'arrive', 'at', 'the', 'airport', 'in', 'Hamburg', 'again', '.', 'right', '?']
# PRED 178: پس ما باید آن را در منزل branch .
# PRED SCORE: -8.9304
#
# SENT 179: ['then', 'everything', 'is', 'sorted', 'out', 'now', '.', 'then', 'we', 'will', 'see', 'each', 'other', 'on', 'August', 'the', 'seventeenth', '.']
# PRED 179: پس این چیز واضح است ، پس بگذارید آن را در شانزدهم جولای برگزار کنیم .
# PRED SCORE: -16.8473
#
# SENT 180: ['okay', '.', 'goodbye', '.']
# PRED 180: باشه . خداحافظ .
# PRED SCORE: -1.2765
#
# SENT 181: ['good', 'morning', '.', 'how', 'are', 'you', '?']
# PRED 181: صبح خوب است . خوب است ؟
# PRED SCORE: -4.0638
#
# SENT 182: ['when', 'should', 'we', 'go', 'to', 'Hanover', '?']
# PRED 182: چه موقع ما باید در Hanover ؟
# PRED SCORE: -4.9986
#
# SENT 183: ['fine', '.', 'let', 'us', 'meet', 'at', 'ten', "o'clock", 'in', 'the', 'morning', '.', 'should', 'we', 'go', 'by', 'train', '?']
# PRED 183: خوب است . پس همدیگر را ساعت ده همدیگر را ملاقات کنیم ، پس ما آنجا در آنجا ؟
# PRED SCORE: -16.2162
#
# SENT 184: ['thanks', '.', 'then', 'we', 'meet', 'at', 'the', 'train', 'station', '.']
# PRED 184: خیلی متشکرم ، از دوازده .
# PRED SCORE: -7.0592
#
# SENT 185: ['when', 'will', 'we', 'arrive', 'in', 'Hanover', '?']
# PRED 185: چه موقع میتوانیم در Hanover ؟
# PRED SCORE: -4.4959
#
# SENT 186: ['I', 'have', 'asked', ',', 'when', 'we', 'will', 'arrive', 'in', 'Hanover', '.']
# PRED 186: من نمیدانم ، باید یک رستوران Hanover .
# PRED SCORE: -7.3316
#
# SENT 187: ['fine', '.', 'I', 'have', 'already', 'reserved', 'a', 'hotel', '.']
# PRED 187: خوب است ، من فکر میکنم کرده­ام hotels .
# PRED SCORE: -6.6004
#
# SENT 188: ['at', 'the', 'hotel', 'Maritim', '.', 'we', 'can', 'go', 'there', 'by', 'taxi', '.']
# PRED 188: در هتل Hanover که ما باید در آنجا برویم .
# PRED SCORE: -11.4662
#
# SENT 189: ['yes', ',', 'I', 'have', 'already', 'booked', 'the', 'hotel', '.']
# PRED 189: بله ، من قبلا asked .
# PRED SCORE: -3.8671
#
# SENT 190: ['I', 'have', 'booked', 'two', 'single', 'rooms', '.', 'one', 'for', 'me', 'and', 'one', 'for', 'you', '.']
# PRED 190: من فقط سه hotels دارم که با آن برای شما comply .
# PRED SCORE: -16.8030
#
# SENT 191: ['in', 'the', 'evening', 'we', 'should', 'watch', 'the', 'newest', 'movie', 'with', 'Arnold', 'Schwarzenegger', '.']
# PRED 191: پس ما باید یک رستوران در دفتر شرکت .
# PRED SCORE: -12.2738
#
# SENT 192: ['fine', '.', 'let', 'us', 'meet', 'at', 'the', 'station', 'at', 'nine', "o'clock", 'on', 'Thursday', 'morning', '.']
# PRED 192: خوب است . پس همدیگر را ساعت ساعت ده صبح ملاقات کنیم .
# PRED SCORE: -6.9922
#
# SENT 193: ['what', 'did', 'you', 'say', ',', 'please', '?']
# PRED 193: نظر شما چیست ، لطفا ؟
# PRED SCORE: -2.2463
#
# SENT 194: ['yes', '.', 'we', 'leave', 'at', 'nine', "o'clock", 'and', 'arrive', 'at', 'Hamburg', 'at', 'one', "o'clock", '.', 'right', '?']
# PRED 194: بله . پس ما ساعت ساعت ده در یک movie . یا یک ؟
# PRED SCORE: -15.2298
#
# SENT 195: ['yes', '.', 'is', 'everything', 'cleared', 'up', 'then', '?']
# PRED 195: بله . آن چیز برای ما دارد ؟
# PRED SCORE: -8.1985
#
# SENT 196: ['then', 'everything', 'is', 'arranged', '.', 'goodbye', '.']
# PRED 196: پس همه چیز را معین کنیم .
# PRED SCORE: -6.1282
#
# SENT 197: ['hello', '.', 'I', 'would', 'prefer', 'the', 'Intercontinental', '.']
# PRED 197: سلام . من ترجیح میدهم .
# PRED SCORE: -4.4792
#
# SENT 198: ['fine', '.', 'let', 'us', 'take', 'the', 'Intercontinental', '.', 'should', 'we', 'fly', '?']
# PRED 198: خوب است ، پس اجازه دهید آن را انتخاب کنیم .
# PRED SCORE: -6.9983
#
# SENT 199: ['no', 'problem', '.', 'then', 'let', 'us', 'meet', '.', 'where', 'should', 'we', 'meet', '?']
# PRED 199: مشکلی نیست ، اجازه دهید ببینیم ، میتوانیم همدیگر را ببینیم ؟
# PRED SCORE: -9.4841
#
# SENT 200: ['yes', ',', 'we', 'take', 'the', 'Atlantic-Hotel', '.']
# PRED 200: بله ، باید آنرا انجام دهیم .
# PRED SCORE: -5.3960
#
# SENT 201: ['thanks', '.', 'by', 'the', 'way', ',', 'we', 'fly', 'to', 'Hanover', '.']
# PRED 201: خیلی متشکرم ، آقای مولرلودنچدیت تا یازده .
# PRED SCORE: -4.1505
#
# SENT 202: ['yes', '.', 'our', 'plane', 'will', 'take', 'off', 'at', 'a', 'quarter', 'to', 'seven', 'and', 'will', 'land', 'at', 'Hanover', 'at', 'ten', 'past', 'ten', '.']
# PRED 202: بله . پس یک ربع و نیم . و یک ربع و ده و ده .
# PRED SCORE: -16.4222
#
# SENT 203: ['fine', '.', 'by', 'taxi', 'we', 'will', 'be', 'at', 'the', 'hotel', 'within', 'ten', 'minutes', '.']
# PRED 203: خوب است . اگر ما آنجا در Hanover در ساعت هشت .
# PRED SCORE: -7.7503
#
# SENT 204: ['yes', ',', 'let', 'us', 'take', 'two', 'single', 'rooms', '.', 'and', 'what', 'would', 'you', 'like', 'to', 'do', 'in', 'the', 'evening', '?']
# PRED 204: بله ، اجازه بدهید دو دو را انتخاب کنیم . آیا شما میخواهید در آن بعدازظهر ؟
# PRED SCORE: -15.3744
#
# SENT 205: ['fine', '.', 'let', 'us', 'go', 'out', 'for', 'a', 'meal', 'in', 'the', 'evening', '.', 'the', 'best', 'would', 'be', 'the', 'Gr"unschnabel', '.']
# PRED 205: خوب است . پس اجازه بدهید یک شام را برای شام هماهنگ کنیم . پس آن زمان خوب است .
# PRED SCORE: -21.2211
#
# SENT 206: ['on', 'Wednesday', 'we', 'will', 'go', 'back', 'by', 'train', 'to', 'Hamburg', '.']
# PRED 206: چهارشنبه به خانه من به خانه بروم .
# PRED SCORE: -9.7426
#
# SENT 207: ['we', 'will', 'leave', 'at', 'half', 'past', 'eight', 'and', 'will', 'arrive', 'at', 'Hamburg', 'at', 'ten', "o'clock", '.']
# PRED 207: ما ساعت دوازده و نیم در دفتر branch .
# PRED SCORE: -11.0009
#
# SENT 208: ['the', 'best', 'thing', 'would', 'be', 'for', 'us', 'to', 'take', 'the', 'subway', 'from', 'our', 'hotel', 'to', 'the', 'station', '.']
# PRED 208: زودترین زمان که در هتل در هتل Luisenhof و Schlosshotel .
# PRED SCORE: -18.5633
#
# SENT 209: ['fine', '.', 'let', 'us', 'go', 'for', 'a', 'little', 'walk', 'in', 'Hamburg', '.']
# PRED 209: خوب است ، پس اجازه ‌بدهید به سفر برویم .
# PRED SCORE: -8.6815
#
# SENT 210: ['I', 'am', 'looking', 'forward', 'to', 'that', '.', 'goodbye', '.']
# PRED 210: من مشتاقانه منتظر آن هستم .
# PRED SCORE: -2.2033
#
# SENT 211: ['hello', '.', 'should', 'we', 'go', 'by', 'car', 'to', 'Hanover', '?']
# PRED 211: سلام . و ما یک بازی شویم ؟
# PRED SCORE: -7.9708
#
# SENT 212: ['we', 'should', 'leave', 'at', 'ten', "o'clock", 'in', 'the', 'morning', 'to', 'be', 'in', 'Hanover', 'at', 'twelve', "o'clock", '.']
# PRED 212: ما باید در ساعت هشت صبح در ساعت هشت .
# PRED SCORE: -9.4305
#
# SENT 213: ['do', 'you', 'want', 'me', 'to', 'book', 'a', 'hotel', '?']
# PRED 213: آیا شما میخواهید به هتل بیایی ؟
# PRED SCORE: -4.8412
#
# SENT 214: ['I', 'will', 'book', 'two', 'single', 'rooms', 'with', 'a', 'shower', 'at', 'the', 'K"onigshotel']
# PRED 214: من دو اتاق را به هتل مراقب دارم .
# PRED SCORE: -9.9922
#
# SENT 215: ['yes', ',', 'I', 'would', 'suggest', 'we', 'fly', 'back', '.']
# PRED 215: بله ، من فکر میکنم ما پرواز میکنم .
# PRED SCORE: -4.7540
#
# SENT 216: ['yes', ',', 'I', 'would', 'suggest', 'the', 'flight', 'at', 'a', 'quarter', 'past', 'seven', '.']
# PRED 216: بله ، من ساعت هشت و نیم را پیشنهاد میکنم .
# PRED SCORE: -3.8961
#
# SENT 217: ['I', 'agree', '.']
# PRED 217: موافقم .
# PRED SCORE: -0.2469
#
# SENT 218: ['we', 'will', 'be', 'back', 'in', 'Hamburg', 'at', 'five', 'past', 'ten', '.']
# PRED 218: ما تا ساعت ده تا پنج آنجا خواهم بود .
# PRED SCORE: -8.4584
#
# SENT 219: ['yes', ',', 'we', 'will', 'be', 'back', 'at', 'Hamburg', 'at', 'five', 'past', 'ten', '.', 'would', 'you', 'like', 'to', 'go', 'to', 'the', 'Wienerwald', 'in', 'Hanover', 'in', 'the', 'evening', '?']
# PRED 219: بله ، ما از ده تا نیم در دفتر branch خواهیم رفت و بعد از آن ؟
# PRED SCORE: -17.0823
#
# SENT 220: ['okay', ',', 'goodbye', '.']
# PRED 220: باشه ، خداحافظ .
# PRED SCORE: -1.4477
#
# SENT 221: ['Mrs', 'Schmidt', ',', 'we', 'still', 'want', 'to', 'plan', 'the', 'journey', 'to', 'Hanover', '.']
# PRED 221: خانم لیوبر ، ما باید یک را در Hanover در Hanover .
# PRED SCORE: -8.7362
#
# SENT 222: ['I', 'would', 'like', 'to', 'take', 'the', 'train', 'on', 'the', 'thirtieth', '.']
# PRED 222: من دوست دارم تا دوازده برگردم .
# PRED SCORE: -6.5367
#
# SENT 223: ['during', 'a', 'flight', 'I', 'always', 'get', 'sick', '.', 'I', 'would', 'like', 'to', 'take', 'the', 'train', '.']
# PRED 223: در آنجایی که من پرواز میکنم که من پرواز میکنم و من باید به خانه میروم .
# PRED SCORE: -18.3567
#
# SENT 224: ['well', ',', 'I', 'would', 'like', 'to', 'take', 'the', 'train', '.', 'during', 'a', 'flight', 'I', 'get', 'sick', '.']
# PRED 224: خب ، من میخواهم یک پرواز دارم تا من آنجا وجود دارد .
# PRED SCORE: -13.6065
#
# SENT 225: ['please', 'let', 'us', 'take', 'the', 'train', '.']
# PRED 225: لطفا در دهید از قطار .
# PRED SCORE: -5.7510
#
# SENT 226: ['let', 'us', 'take', 'the', 'train', 'at', 'nine', "o'clock", '.']
# PRED 226: اجازه دهید از نه تا نه .
# PRED SCORE: -5.6734
#
# SENT 227: ['at', 'six', 'past', 'nine', 'then', '.', 'then', 'let', 'us', 'meet', 'at', 'the', 'station', 'at', 'half', 'past', 'eight', '.']
# PRED 227: ساعت شش و نیم ، پس ما میتوانیم از دوازده و نیم .
# PRED SCORE: -12.0667
#
# SENT 228: ['when', 'do', 'we', 'arrive', 'at', 'Hanover', '?']
# PRED 228: چه موقع میتوانیم در Hanover ؟
# PRED SCORE: -4.3574
#
# SENT 229: ['that', 'is', 'very', 'good', '.', 'at', 'which', 'hotel', 'should', 'we', 'stay', 'then', '?', 'what', 'about', 'the', 'Gr"unschnabel', '?']
# PRED 229: خیلی خیلی خوب است . اما در هتل چطور است . یا آن چطور است ؟
# PRED SCORE: -16.7114
#
# SENT 230: ['I', 'think', 'we', 'will', 'take', 'the', 'Metropol', 'hotel', '.', 'could', 'you', 'reserve', 'two', 'single', 'rooms', '?']
# PRED 230: من فکر میکنم که شما را در هتل در هتل خواهیم دید و شما اتاق را در نظر شما ؟
# PRED SCORE: -25.7733
#
# SENT 231: ['that', 'is', 'perfect', '.', 'would', 'you', 'like', 'to', 'go', 'out', 'for', 'a', 'meal', 'in', 'the', 'evening', '?']
# PRED 231: عالی است . اگر شما میخواهید برای شام کاری ؟
# PRED SCORE: -11.1112
#
# SENT 232: ['yes', ',', 'the', 'steaks', 'at', 'the', 'Block-House', 'are', 'always', 'very', 'succulent', '.']
# PRED 232: بله ، در واقع همیشه همیشه centrally located است .
# PRED SCORE: -9.3714
#
# SENT 233: ['good', 'idea', '.', 'we', 'could', 'take', 'the', 'one', 'at', 'the', 'Maschsee', '.']
# PRED 233: خوب است ، ما میتوانیم آن را در یک اتاق .
# PRED SCORE: -10.8512
#
# SENT 234: ['that', 'is', 'perfect', '.', 'then', 'we', 'have', 'talked', 'about', 'everything', '.', 'goodbye', '.']
# PRED 234: خیلی عالی است که ما درباره آن صحبت کردیم .
# PRED SCORE: -10.9731
#
# SENT 235: ['hello', '.', 'we', 'still', 'have', 'to', 'plan', 'our', 'trip', 'to', 'Hanover', '.']
# PRED 235: سلام . اما ما هنوز باید یک جلسه را در Hanover .
# PRED SCORE: -10.8790
#
# SENT 236: ['I', 'would', 'like', 'to', 'fly', '.', 'that', 'looks', 'more', 'important', '.']
# PRED 236: من دوست دارم که آن خوب به نظر میرسد .
# PRED SCORE: -9.7750
#
# SENT 237: ['the', 'earliest', 'flight', 'leaves', 'at', 'five', 'past', 'eight', '.', 'should', 'we', 'take', 'that', 'one', '?']
# PRED 237: پس فقط از آن ساعت شش عصر و بعد از ساعت شش شروع دارد ؟
# PRED SCORE: -19.1994
#
# SENT 238: ['the', 'plane', 'arrives', 'at', 'Hanover', 'at', 'a', 'quarter', 'past', 'eleven', '.']
# PRED 238: Hanover شما Hanover ساعت ساعت نه و یازده .
# PRED SCORE: -9.7532
#
# SENT 239: ['let', 'us', 'meet', 'at', 'seven', "o'clock", '.', 'we', 'still', 'have', 'to', 'check', 'in', '.']
# PRED 239: اجازه بدهید ساعت ده همدیگر را ملاقات کنیم ، ما میتوانیم آن را ببینیم .
# PRED SCORE: -9.3573
#
# SENT 240: ['what', 'do', 'you', 'think', 'about', 'the', 'hotel', 'Gewandhaus', '?']
# PRED 240: نظرت درباره آن چیست ؟
# PRED SCORE: -4.1417
#
# SENT 241: ['I', 'would', 'like', 'one', ',', 'I', 'would', 'like', 'to', 'have', 'one', 'single', 'room', '.']
# PRED 241: من دوست‌ دارم ، من باید یک جلسه را در دو hotels .
# PRED SCORE: -16.9594
#
# SENT 242: ['you', 'would', 'like', 'to', 'have', 'a', 'room', 'with', 'TV', 'and', 'Bar', '?']
# PRED 242: شما باید به یک اتاق قهوه با یک بیایی ؟
# PRED SCORE: -13.1403
#
# SENT 243: ['I', 'will', 'book', 'the', 'hotelroom', '.']
# PRED 243: من آن را رزرو میکنم .
# PRED SCORE: -3.7884
#
# SENT 244: ['we', 'have', 'already', 'agreed', 'on', 'the', 'hotel', '.']
# PRED 244: ما آن را در Hanover .
# PRED SCORE: -5.7480
#
# SENT 245: ['unfortunately', 'I', 'did', 'not', 'understand', 'that', '.']
# PRED 245: متاسفانه آن را نفهمیدم .
# PRED SCORE: -2.6022
#
# SENT 246: ['let', 'us', 'leave', 'at', 'eight', "o'clock", '$P-$M', '.', 'there', 'is', 'a', 'flight', 'to', 'Hamburg', 'going', 'over', 'Milan', '.', "isn't", 'that', 'great', '?']
# PRED 246: اجازه دهید ساعت هشت و یک ربع در دفتر branch . پس برای شما مناسب است ؟
# PRED SCORE: -18.3420
#
# SENT 247: ['let', 'yourself', 'get', 'surprised', '!']
# PRED 247: اجازه دهید دعوتتان کنم .
# PRED SCORE: -4.5073
#
# SENT 248: ['I', 'could', ',', 'but', 'I', "don't", 'do', 'it', '.']
# PRED 248: من میتوانم ، من میتوانم آن را انجام دهم .
# PRED SCORE: -7.1398
#
# SENT 249: ['at', 'eight', "o'clock", '$P-$M', '.']
# PRED 249: ساعت شش عصر .
# PRED SCORE: -0.9986
#
# SENT 250: ['yes', ',', 'that', 'is', 'in', 'the', 'evening', '.', 'now', 'we', 'have', 'talked', 'about', 'everything', '.', 'goodbye', '.']
# PRED 250: بله ، آن است ، ما هتل را در هتل Zentral صحبت میکنیم .
# PRED SCORE: -13.7920
# PRED AVG SCORE: -0.9089, PRED PPL: 2.4816

# %%
# !perl  OpenNMT-py/tools/multi-bleu.perl \
./Corpora/En2Fa-Translation/Test/test.fa0 \
./Corpora/En2Fa-Translation/Test/test.fa1 \
./Corpora/En2Fa-Translation/Test/test.fa2 \
./Corpora/En2Fa-Translation/Test/test.fa3 < ./predictions/test.txt

# %%
results = open('./stats.txt', 'r')
accuracies = []
steps = []
perplexities = []
for line in results:
    line = line.rstrip()
    if 'acc:' in line:
        print(line)
        accuracies.append(
            float(line[line.index('acc:')+6:line.index('ppl:')-2])
        )
        perplexities.append(
            float(line[line.index('ppl:')+5:line.index('xent:')-2])
        )
        steps.append(
            int(line[line.index('Step')+5:line.index('/50000')])
        )

# %%
plt.plot(steps, accuracies)
plt.title('Train data accuracy')
plt.xlabel('steps')
plt.ylabel('accuracy')
plt.figure()
plt.plot(steps, perplexities)
plt.title('Train data perplexity')
plt.xlabel('steps')
plt.ylabel('perplexity')

# %%
results = open('./bleu_results.txt', 'r')
bleu_scores = []
steps = []
for line in results:
    line = line.rstrip()
    bleu_scores.append(
        float(line[line.index('BLEU')+7:line.index(',')])
    )
    steps.append(int(line[:line.index('BLEU')-3])*0.1)

# %%
plt.figure()
plt.plot(steps, bleu_scores)
plt.title('Train data BLEU')
plt.xlabel('steps (k)')
plt.ylabel('BLEU')

# %%
# !python OpenNMT-py/train.py \
# -data ./data/trans \
# -src_word_vec_size 512 \
# -tgt_word_vec_size 512 \
# -encoder_type "rnn" \
# -decoder_type "rnn" \
# -layers 6 \
# -rnn_size 256 \
# -rnn_type "GRU" \
# -save_model ./models/trans \
# -save_checkpoint_steps 2500 \
# -gpu_ranks 0 \
# -world_size 1 \
# -seed 2020 \
# -batch_size 32 \
# -normalization "sents" \
# -train_steps 50000 \
# -early_stopping 0 \
# -optim "adam" \
# -max_grad_norm 5 \
# -dropout 0.4 \
# -learning_rate 0.001 \
# -learning_rate_decay 0.8 \
# -start_decay_steps 10000 \
# -decay_steps 5000 \
# -decay_method "none" \
# -warmup_steps 1000 \
# -report_every 500 \
# -log_file "stats.txt"
